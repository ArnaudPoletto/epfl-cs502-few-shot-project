# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Define colors for ["ProtoNet", "MatchingNet", "MAML", "RelationNet"]
colors = {
    "ProtoNet": "#1f77b4",
    "MatchingNet": "#ff7f0e",
    "MAML": "#2ca02c",
    "RelationNet": "#d62728",
}

# %%
header = ["timestamp", "dataset", "name", "split", "acc_mean", "acc_std", "n_way", "n_shot", "n_query", "learning_rate", "backbone_weight_decay", "backbone_dropout"]
df = pd.read_csv("./../results.csv", names=header, header=0, usecols=header[:9])
df.head()
# Out:
#          timestamp       dataset            name  split   acc_mean    acc_std  \
# 0  20231208-225716  tabula_muris  protonet_5w_1s  train  92.093333   9.225899
# 1  20231208-225716  tabula_muris  protonet_5w_1s    val  81.380000  12.343991
# 2  20231208-225716  tabula_muris  protonet_5w_1s   test  81.153333  11.620680
# 3  20231208-230011  tabula_muris  protonet_5w_5s  train  98.342222   2.757601
# 4  20231208-230011  tabula_muris  protonet_5w_5s    val  89.228889   7.458193
#
#    n_way  n_shot  n_query
# 0      5       1       15
# 1      5       1       15
# 2      5       1       15
# 3      5       5       15
# 4      5       5       15

# %%
# Take all the results for tabula_muris on the test split
t_test = df[(df["dataset"] == "tabula_muris") & (df["split"] == "test")]
t_test.head()
# Out:
#           timestamp       dataset             name split   acc_mean  \
# 2   20231208-225716  tabula_muris   protonet_5w_1s  test  81.153333
# 5   20231208-230011  tabula_muris   protonet_5w_5s  test  89.300000
# 8   20231208-230306  tabula_muris  protonet_5w_10s  test  90.406667
# 11  20231208-230603  tabula_muris  protonet_5w_20s  test  91.371111
# 14  20231208-230900  tabula_muris  protonet_5w_30s  test  89.773333
#
#       acc_std  n_way  n_shot  n_query
# 2   11.620680      5       1       15
# 5    7.533555      5       5       15
# 8    7.017900      5      10       15
# 11   6.571660      5      20       15
# 14   7.063869      5      30       15

# %%
t_test[t_test["name"].str.endswith("conc_sum_7lg_2lf")]
# Out:
#            timestamp       dataset                                    name  \
# 119  20231209-074307  tabula_muris   relationnet_5w_1s_fc-conc_sum_7lg_2lf
# 122  20231209-074601  tabula_muris   relationnet_5w_5s_fc-conc_sum_7lg_2lf
# 125  20231209-074850  tabula_muris  relationnet_5w_10s_fc-conc_sum_7lg_2lf
# 128  20231209-075153  tabula_muris  relationnet_5w_20s_fc-conc_sum_7lg_2lf
# 131  20231209-075439  tabula_muris  relationnet_5w_30s_fc-conc_sum_7lg_2lf
# 134  20231209-075724  tabula_muris  relationnet_5w_40s_fc-conc_sum_7lg_2lf
# 137  20231209-080017  tabula_muris  relationnet_5w_50s_fc-conc_sum_7lg_2lf
# 140  20231209-080315  tabula_muris  relationnet_5w_70s_fc-conc_sum_7lg_2lf
# 143  20231209-080611  tabula_muris  relationnet_5w_90s_fc-conc_sum_7lg_2lf
# 146  20231209-080902  tabula_muris  relationnet_10w_5s_fc-conc_sum_7lg_2lf
# 149  20231209-081155  tabula_muris  relationnet_20w_5s_fc-conc_sum_7lg_2lf
# 152  20231209-081457  tabula_muris  relationnet_30w_5s_fc-conc_sum_7lg_2lf
# 155  20231209-081805  tabula_muris  relationnet_40w_5s_fc-conc_sum_7lg_2lf
# 158  20231209-082126  tabula_muris  relationnet_50w_5s_fc-conc_sum_7lg_2lf
# 245  20231209-140650  tabula_muris   relationnet_5w_5s_fc-conc_sum_7lg_2lf
#
#     split   acc_mean    acc_std  n_way  n_shot  n_query
# 119  test  70.586667  13.178191      5       1       15
# 122  test  80.680000  10.305545      5       5       15
# 125  test  81.235556  10.084792      5      10       15
# 128  test  83.553333   9.029608      5      20       15
# 131  test  78.604444  10.711668      5      30       15
# 134  test  81.324444   8.972381      5      40       15
# 137  test  77.542222   9.562469      5      50       15
# 140  test  81.055556   9.230699      5      70       15
# 143  test  81.113333  10.100336      5      90       15
# 146  test  64.492222   8.056280     10       5       15
# 149  test  52.816667   5.337125     20       5       15
# 152  test  45.577778   3.076420     30       5       15
# 155  test  38.957099   2.333304     40       5       15
# 158  test  31.070679   1.996717     50       5       15
# 245  test  78.866667  10.288649      5       5       15

# %%
# in the name column, we take all of them, but for the ones that begin with "relationnet_" we only keep those that end with "fc-conc_sum_7lg_2lf"
t_test_all = t_test[~t_test["name"].str.startswith("relationnet_")]
# Now we only keep the ones that end with "fc-conc_sum_7lg_2lf"
t_test_all = t_test_all[t_test_all["name"].str.endswith("fc-conc_sum_7lg_2lf")]
t_test_all.head()
# Out:
# Empty DataFrame
# Columns: [timestamp, dataset, name, split, acc_mean, acc_std, n_way, n_shot, n_query]
# Index: []

# %%
# in the name column, we take all but for the ones that begin with "relationnet_", we only keep those that end with "fc-conc_sum_7lg_2lf"
t_test_all = t_test[~t_test["name"].str.startswith("relationnet_")]
# For relationnet, we take those with timestamp greater or equal to 20231212-162623
t_test_relationnet = t_test[t_test["name"].str.startswith("relationnet_") & (t_test["timestamp"] >= "20231212-162623")]
# We concatenate the two dataframes
t_test = pd.concat([t_test_all, t_test_relationnet])
# Remove the last element in the frame
#t_test = t_test[:-1]

# %%
ALPHA=0.1
figsize=(16, 9)
fontsize=15
# We make a plot for wich the ways=5, and the shots vary
fig, ax = plt.subplots(2, 2, figsize=figsize, tight_layout=True)
sns.set(style="darkgrid")
for name in ["ProtoNet", "MatchingNet", "MAML", "RelationNet"]:
    data = t_test[t_test["name"].str.startswith(name.lower()) & (t_test["n_way"] == 5)]
    sns.lineplot(x="n_shot", y="acc_mean", data=data, label=name, color=colors[name], ax=ax[0, 0])
    # We fill between with the acc_std
    ax[0, 0].fill_between(data['n_shot'], data['acc_mean'] - data['acc_std'], data['acc_mean'] + data['acc_std'], alpha=ALPHA, color=colors[name])
ax[0, 0].set_ylabel('Mean accuracy', fontsize=fontsize)
ax[0, 0].set_xlabel(None)
ax[0, 0].set_title('5-way K-shot test accuracy for TM', fontsize=fontsize)
ax[0, 0].tick_params(axis='both', which='major', labelsize=fontsize)
ax[0, 0].legend(fontsize=fontsize)
# Make the x axis begin at 1
ax[0, 0].set_xlim(left=1)
# Show ticks only at 1, 20, 40, 60 and 80
ax[0, 0].set_xticks([1, 20, 40, 60, 80])
#plt.savefig('../generated/5-way_K-shot_test_accuracy.png', dpi=300)
#plt.show()
t_test[t_test["name"].str.startswith("relatio".lower()) & (t_test["n_shot"] == 5)]
# Now we do the same but shots=5 and ways vary
for name in ["ProtoNet", "MatchingNet", "RelationNet"]:
    data = t_test[t_test["name"].str.startswith(name.lower()) & (t_test["n_shot"] == 5)]
    sns.lineplot(x="n_way", y="acc_mean", data=data, label=name, color=colors[name], ax=ax[0, 1])
    # We fill between with the acc_std
    ax[0, 1].fill_between(data['n_way'], data['acc_mean'] - data['acc_std'], data['acc_mean'] + data['acc_std'], alpha=ALPHA, color=colors[name])
ax[0, 1].set_ylabel(None)
ax[0, 1].set_xlabel(None)
ax[0, 1].set_title('C-way 5-shot test accuracy for TM', fontsize=fontsize)
ax[0, 1].tick_params(axis='both', which='major', labelsize=fontsize)
ax[0, 1].legend(fontsize=fontsize)
# Make the x axis begin at 5
ax[0, 1].set_xlim(left=5)
# Show ticks only at 5, 10, 20, 30, 40, 50
ax[0, 1].set_xticks([5, 10, 20, 30, 40, 50]) 
# Now we do the same, but for the swissprot dataset
s_test = df[(df["dataset"] == "swissprot") & (df["split"] == "test")]
s_test.head()

s_test_all = s_test[~s_test["name"].str.startswith("relationnet_")]
s_test_relationnet = s_test[s_test["name"].str.startswith("relationnet_") & (s_test["timestamp"] >= "20231212-162623")]
s_test = pd.concat([s_test_all, s_test_relationnet])
#s_test = s_test[:-1]

# We make a plot for wich the ways=5, and the shots vary
for name in ["ProtoNet", "MatchingNet", "MAML", "RelationNet"]:
    data = s_test[s_test["name"].str.startswith(name.lower()) & (s_test["n_way"] == 5)]
    sns.lineplot(x="n_shot", y="acc_mean", data=data, label=name, color=colors[name], ax=ax[1, 0])
    # We fill between with the acc_std
    ax[1, 0].fill_between(data['n_shot'], data['acc_mean'] - data['acc_std'], data['acc_mean'] + data['acc_std'], alpha=ALPHA, color=colors[name])
ax[1, 0].set_ylabel('Mean accuracy', fontsize=fontsize)
ax[1, 0].set_xlabel('Number of shots', fontsize=fontsize)
ax[1, 0].set_title('5-way K-shot test accuracy for SP', fontsize=fontsize)
ax[1, 0].tick_params(axis='both', which='major', labelsize=fontsize)
ax[1, 0].legend(fontsize=fontsize)
# Make the x axis begin at 1
ax[1, 0].set_xlim(left=1)
# Show ticks only at 1, 20, 40, 60 and 80
ax[1, 0].set_xticks([1, 20, 40, 60, 80])
# Now we do the same but shots=5 and ways vary
for name in ["ProtoNet", "MatchingNet", "RelationNet"]:
    data = s_test[s_test["name"].str.startswith(name.lower()) & (s_test["n_shot"] == 5)]
    sns.lineplot(x="n_way", y="acc_mean", data=data, label=name, color=colors[name], ax=ax[1, 1])
    # We fill between with the acc_std
    ax[1, 1].fill_between(data['n_way'], data['acc_mean'] - data['acc_std'], data['acc_mean'] + data['acc_std'], alpha=ALPHA, color=colors[name])
ax[1, 1].set_ylabel(None)
ax[1, 1].set_xlabel('Number of ways', fontsize=fontsize)
ax[1, 1].set_title('C-way 5-shot test accuracy for SP', fontsize=fontsize)
ax[1, 1].tick_params(axis='both', which='major', labelsize=fontsize)
ax[1, 1].legend(fontsize=fontsize)
# Make the x axis begin at 5
ax[1, 1].set_xlim(left=5)
# Show ticks only at 5, 10, 20, 30, 40, 50
ax[1, 1].set_xticks([5, 10, 20, 30, 40, 50])
fig.suptitle("Ways and shots analysis for Tabula Muris and SwissProt", fontsize=fontsize*1.2)
plt.savefig('../generated/ways_shots.png', dpi=300)
plt.show()

# %%
# Define colors for ["ProtoNet", "MatchingNet", "MAML", "RelationNet"]
colors = {
    "ProtoNet": "#1f77b4",
    "MatchingNet": "#ff7f0e",
    "MAML": "#2ca02c",
    "RelationNet": "#d62728",
}

# %%
# Take all the results for tabula_muris on the test split
t_test = df[(df["dataset"] == "tabula_muris") & (df["split"] == "test")]
t_test.head()
# Out:
#           timestamp       dataset             name split   acc_mean  \
# 2   20231208-225716  tabula_muris   protonet_5w_1s  test  81.153333
# 5   20231208-230011  tabula_muris   protonet_5w_5s  test  89.300000
# 8   20231208-230306  tabula_muris  protonet_5w_10s  test  90.406667
# 11  20231208-230603  tabula_muris  protonet_5w_20s  test  91.371111
# 14  20231208-230900  tabula_muris  protonet_5w_30s  test  89.773333
#
#       acc_std  n_way  n_shot  n_query
# 2   11.620680      5       1       15
# 5    7.533555      5       5       15
# 8    7.017900      5      10       15
# 11   6.571660      5      20       15
# 14   7.063869      5      30       15

# %%
# in the name column, we take all of them, but for the ones that begin with "relationnet_" we only keep those that end with "fc-conc_sum_7lg_2lf"
t_test_all = t_test[~t_test["name"].str.startswith("relationnet_")]
# Now we only keep the ones that end with "fc-conc_sum_7lg_2lf"
t_test_all = t_test_all[t_test_all["name"].str.endswith("fc-conc_sum_7lg_2lf")]
t_test_all.head()
# Out:
# Empty DataFrame
# Columns: [timestamp, dataset, name, split, acc_mean, acc_std, n_way, n_shot, n_query]
# Index: []

# %%
ALPHA=0.1
figsize=(16, 9)
fontsize=15
# We make a plot for wich the ways=5, and the shots vary
fig, ax = plt.subplots(2, 2, figsize=figsize, tight_layout=True)
sns.set(style="darkgrid")
for name in ["ProtoNet", "MatchingNet", "MAML", "RelationNet"]:
    data = t_test[t_test["name"].str.startswith(name.lower()) & (t_test["n_way"] == 5)]
    sns.lineplot(x="n_shot", y="acc_mean", data=data, label=name, color=colors[name], ax=ax[0, 0])
    # We fill between with the acc_std
    ax[0, 0].fill_between(data['n_shot'], data['acc_mean'] - data['acc_std'], data['acc_mean'] + data['acc_std'], alpha=ALPHA, color=colors[name])
ax[0, 0].set_ylabel('Mean accuracy', fontsize=fontsize)
ax[0, 0].set_xlabel(None)
ax[0, 0].set_title('5-way K-shot test accuracy for TM', fontsize=fontsize)
ax[0, 0].tick_params(axis='both', which='major', labelsize=fontsize)
ax[0, 0].legend(fontsize=fontsize)
# Make the x axis begin at 1
ax[0, 0].set_xlim(left=1)
# Show ticks only at 1, 20, 40, 60 and 80
ax[0, 0].set_xticks([1, 20, 40, 60, 80])
#plt.savefig('../generated/5-way_K-shot_test_accuracy.png', dpi=300)
#plt.show()
t_test[t_test["name"].str.startswith("relatio".lower()) & (t_test["n_shot"] == 5)]
# Now we do the same but shots=5 and ways vary
for name in ["ProtoNet", "MatchingNet", "RelationNet"]:
    data = t_test[t_test["name"].str.startswith(name.lower()) & (t_test["n_shot"] == 5)]
    sns.lineplot(x="n_way", y="acc_mean", data=data, label=name, color=colors[name], ax=ax[0, 1])
    # We fill between with the acc_std
    ax[0, 1].fill_between(data['n_way'], data['acc_mean'] - data['acc_std'], data['acc_mean'] + data['acc_std'], alpha=ALPHA, color=colors[name])
ax[0, 1].set_ylabel(None)
ax[0, 1].set_xlabel(None)
ax[0, 1].set_title('C-way 5-shot test accuracy for TM', fontsize=fontsize)
ax[0, 1].tick_params(axis='both', which='major', labelsize=fontsize)
ax[0, 1].legend(fontsize=fontsize)
# Make the x axis begin at 5
ax[0, 1].set_xlim(left=5)
# Show ticks only at 5, 10, 20, 30, 40, 50
ax[0, 1].set_xticks([5, 10, 20, 30, 40, 50])
# Now we do the same, but for the swissprot dataset
s_test = df[(df["dataset"] == "swissprot") & (df["split"] == "test")]
s_test.head()

s_test_all = s_test[~s_test["name"].str.startswith("relationnet_")]
s_test_relationnet = s_test[s_test["name"].str.startswith("relationnet_") & (s_test["timestamp"] >= "20231212-162623")]
s_test = pd.concat([s_test_all, s_test_relationnet])
#s_test = s_test[:-1]

# We make a plot for wich the ways=5, and the shots vary
for name in ["ProtoNet", "MatchingNet", "MAML", "RelationNet"]:
    data = s_test[s_test["name"].str.startswith(name.lower()) & (s_test["n_way"] == 5)]
    sns.lineplot(x="n_shot", y="acc_mean", data=data, label=name, color=colors[name], ax=ax[1, 0])
    # We fill between with the acc_std
    ax[1, 0].fill_between(data['n_shot'], data['acc_mean'] - data['acc_std'], data['acc_mean'] + data['acc_std'], alpha=ALPHA, color=colors[name])
ax[1, 0].set_ylabel('Mean accuracy', fontsize=fontsize)
ax[1, 0].set_xlabel('Number of shots', fontsize=fontsize)
ax[1, 0].set_title('5-way K-shot test accuracy for SP', fontsize=fontsize)
ax[1, 0].tick_params(axis='both', which='major', labelsize=fontsize)
ax[1, 0].legend(fontsize=fontsize)
# Make the x axis begin at 1
ax[1, 0].set_xlim(left=1)
# Show ticks only at 1, 20, 40, 60 and 80
ax[1, 0].set_xticks([1, 20, 40, 60, 80])
# Now we do the same but shots=5 and ways vary
for name in ["ProtoNet", "MatchingNet", "RelationNet"]:
    data = s_test[s_test["name"].str.startswith(name.lower()) & (s_test["n_shot"] == 5)]
    sns.lineplot(x="n_way", y="acc_mean", data=data, label=name, color=colors[name], ax=ax[1, 1])
    # We fill between with the acc_std
    ax[1, 1].fill_between(data['n_way'], data['acc_mean'] - data['acc_std'], data['acc_mean'] + data['acc_std'], alpha=ALPHA, color=colors[name])
ax[1, 1].set_ylabel(None)
ax[1, 1].set_xlabel('Number of ways', fontsize=fontsize)
ax[1, 1].set_title('C-way 5-shot test accuracy for SP', fontsize=fontsize)
ax[1, 1].tick_params(axis='both', which='major', labelsize=fontsize)
ax[1, 1].legend(fontsize=fontsize)
# Make the x axis begin at 5
ax[1, 1].set_xlim(left=5)
# Show ticks only at 5, 10, 20, 30, 40, 50
ax[1, 1].set_xticks([5, 10, 20, 30, 40, 50])
fig.suptitle("Ways and shots analysis for Tabula Muris and SwissProt", fontsize=fontsize*1.2)
plt.savefig('../generated/ways_shots.png', dpi=300)
plt.show()
