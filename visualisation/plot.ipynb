# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

CSV_FOLDER = '../csv/tabula-muris_'

# %%
# Read all files in the CSV folder as seperate dataframes
# Here we do all the 5-ways K-shots analysis
relationnet_fc_diff_mean_05_k = pd.read_csv(CSV_FOLDER + 'relationnet_fc_diff_mean_05_k.csv')
relationnet_l1_mean_05_k = pd.read_csv(CSV_FOLDER + 'relationnet_l1_mean_05_k.csv')
protonet_05_k = pd.read_csv(CSV_FOLDER + 'protonet_05_k.csv')
matchingnet_05_k = pd.read_csv(CSV_FOLDER + 'matchingnet_05_k.csv')
maml_05_k = pd.read_csv(CSV_FOLDER + 'maml_05_k.csv')

# %%
relationnet_fc_diff_mean_05_k.head()
# Out:
#                                           name   class  split   acc_mean  \
# 0  tabula-muris_relationnet_fc-diff_mean_05_01  s2_5_1  train  92.451111
# 1  tabula-muris_relationnet_fc-diff_mean_05_01  s2_5_1    val  76.348889
# 2  tabula-muris_relationnet_fc-diff_mean_05_01  s2_5_1   test  75.311111
# 3  tabula-muris_relationnet_fc-diff_mean_05_05  s2_5_5  train  96.951111
# 4  tabula-muris_relationnet_fc-diff_mean_05_05  s2_5_5    val  86.542222
#
#      acc_std  n_way  n_shot  n_query
# 0   8.194365      5       1       15
# 1  13.480072      5       1       15
# 2  12.228180      5       1       15
# 3   4.127843      5       5       15
# 4   9.548127      5       5       15

# %%
# We make where the x axis is the number of shots and the y axis is the mean accuracy, with the standard deviation as error bars

ALPHA=0.1

# For the val split:
# RelationNet
relationnet_fc_diff_mean_05_k_val = relationnet_fc_diff_mean_05_k[relationnet_fc_diff_mean_05_k['split'] == 'val']
relationnet_fc_diff_mean_05_k_val = relationnet_fc_diff_mean_05_k_val.sort_values(by=['n_shot'])
relationnet_fc_diff_mean_05_k_val.head()
# plot it
plt.figure(figsize=(10, 5))
sns.set(style="darkgrid")
# We add the standard deviation as error bars filled between
sns.lineplot(x='n_shot', y='acc_mean', data=relationnet_fc_diff_mean_05_k_val, label='RelationNet')
plt.fill_between(relationnet_fc_diff_mean_05_k_val['n_shot'], relationnet_fc_diff_mean_05_k_val['acc_mean'] - relationnet_fc_diff_mean_05_k_val['acc_std'], relationnet_fc_diff_mean_05_k_val['acc_mean'] + relationnet_fc_diff_mean_05_k_val['acc_std'], alpha=ALPHA)

# RelationNet L1
relationnet_l1_mean_05_k_val = relationnet_l1_mean_05_k[relationnet_l1_mean_05_k['split'] == 'val']
relationnet_l1_mean_05_k_val = relationnet_l1_mean_05_k_val.sort_values(by=['n_shot'])
relationnet_l1_mean_05_k_val.head()
# plot it
sns.lineplot(x='n_shot', y='acc_mean', data=relationnet_l1_mean_05_k_val, label='RelationNet L1')
plt.fill_between(relationnet_l1_mean_05_k_val['n_shot'], relationnet_l1_mean_05_k_val['acc_mean'] - relationnet_l1_mean_05_k_val['acc_std'], relationnet_l1_mean_05_k_val['acc_mean'] + relationnet_l1_mean_05_k_val['acc_std'], alpha=ALPHA)

# ProtoNet
protonet_05_k_val = protonet_05_k[protonet_05_k['split'] == 'val']
protonet_05_k_val = protonet_05_k_val.sort_values(by=['n_shot'])
protonet_05_k_val.head()
# plot it
sns.lineplot(x='n_shot', y='acc_mean', data=protonet_05_k_val, label='ProtoNet')
plt.fill_between(protonet_05_k_val['n_shot'], protonet_05_k_val['acc_mean'] - protonet_05_k_val['acc_std'], protonet_05_k_val['acc_mean'] + protonet_05_k_val['acc_std'], alpha=ALPHA)

# MatchingNet
matchingnet_05_k_val = matchingnet_05_k[matchingnet_05_k['split'] == 'val']
matchingnet_05_k_val = matchingnet_05_k_val.sort_values(by=['n_shot'])
matchingnet_05_k_val.head()
# plot it
sns.lineplot(x='n_shot', y='acc_mean', data=matchingnet_05_k_val, label='MatchingNet')
plt.fill_between(matchingnet_05_k_val['n_shot'], matchingnet_05_k_val['acc_mean'] - matchingnet_05_k_val['acc_std'], matchingnet_05_k_val['acc_mean'] + matchingnet_05_k_val['acc_std'], alpha=ALPHA)

# MAML
maml_05_k_val = maml_05_k[maml_05_k['split'] == 'val']
maml_05_k_val = maml_05_k_val.sort_values(by=['n_shot'])
maml_05_k_val.head()
# plot it
sns.lineplot(x='n_shot', y='acc_mean', data=maml_05_k_val, label='MAML')
plt.fill_between(maml_05_k_val['n_shot'], maml_05_k_val['acc_mean'] - maml_05_k_val['acc_std'], maml_05_k_val['acc_mean'] + maml_05_k_val['acc_std'], alpha=ALPHA)

plt.ylabel('Mean accuracy')
plt.xlabel('Number of shots')
plt.title('5-way K-shot validation accuracy')
plt.savefig('../plots/5-way_K-shot_validation_accuracy.png', dpi=300)
plt.show()

# %%
# Now we do the same for the test split:
# RelationNet
relationnet_fc_diff_mean_05_k_test = relationnet_fc_diff_mean_05_k[relationnet_fc_diff_mean_05_k['split'] == 'test']
relationnet_fc_diff_mean_05_k_test = relationnet_fc_diff_mean_05_k_test.sort_values(by=['n_shot'])
relationnet_fc_diff_mean_05_k_test.head()
# plot it
plt.figure(figsize=(10, 5))
sns.set(style="darkgrid")
# We add the standard deviation as error bars filled between
sns.lineplot(x='n_shot', y='acc_mean', data=relationnet_fc_diff_mean_05_k_test, label='RelationNet')
plt.fill_between(relationnet_fc_diff_mean_05_k_test['n_shot'], relationnet_fc_diff_mean_05_k_test['acc_mean'] - relationnet_fc_diff_mean_05_k_test['acc_std'], relationnet_fc_diff_mean_05_k_test['acc_mean'] + relationnet_fc_diff_mean_05_k_test['acc_std'], alpha=ALPHA)

# RelationNet L1
relationnet_l1_mean_05_k_test = relationnet_l1_mean_05_k[relationnet_l1_mean_05_k['split'] == 'test']
relationnet_l1_mean_05_k_test = relationnet_l1_mean_05_k_test.sort_values(by=['n_shot'])
relationnet_l1_mean_05_k_test.head()
# plot it
sns.lineplot(x='n_shot', y='acc_mean', data=relationnet_l1_mean_05_k_test, label='RelationNet L1')
plt.fill_between(relationnet_l1_mean_05_k_test['n_shot'], relationnet_l1_mean_05_k_test['acc_mean'] - relationnet_l1_mean_05_k_test['acc_std'], relationnet_l1_mean_05_k_test['acc_mean'] + relationnet_l1_mean_05_k_test['acc_std'], alpha=ALPHA)

# ProtoNet
protonet_05_k_test = protonet_05_k[protonet_05_k['split'] == 'test']
protonet_05_k_test = protonet_05_k_test.sort_values(by=['n_shot'])
protonet_05_k_test.head()
# plot it
sns.lineplot(x='n_shot', y='acc_mean', data=protonet_05_k_test, label='ProtoNet')
plt.fill_between(protonet_05_k_test['n_shot'], protonet_05_k_test['acc_mean'] - protonet_05_k_test['acc_std'], protonet_05_k_test['acc_mean'] + protonet_05_k_test['acc_std'], alpha=ALPHA)

# MatchingNet
matchingnet_05_k_test = matchingnet_05_k[matchingnet_05_k['split'] == 'test']
matchingnet_05_k_test = matchingnet_05_k_test.sort_values(by=['n_shot'])
matchingnet_05_k_test.head()
# plot it
sns.lineplot(x='n_shot', y='acc_mean', data=matchingnet_05_k_test, label='MatchingNet')
plt.fill_between(matchingnet_05_k_test['n_shot'], matchingnet_05_k_test['acc_mean'] - matchingnet_05_k_test['acc_std'], matchingnet_05_k_test['acc_mean'] + matchingnet_05_k_test['acc_std'], alpha=ALPHA)

# MAML
maml_05_k_test = maml_05_k[maml_05_k['split'] == 'test']
maml_05_k_test = maml_05_k_test.sort_values(by=['n_shot'])
maml_05_k_test.head()
# plot it
sns.lineplot(x='n_shot', y='acc_mean', data=maml_05_k_test, label='MAML')
plt.fill_between(maml_05_k_test['n_shot'], maml_05_k_test['acc_mean'] - maml_05_k_test['acc_std'], maml_05_k_test['acc_mean'] + maml_05_k_test['acc_std'], alpha=ALPHA)

plt.ylabel('Mean accuracy')
plt.xlabel('Number of shots')
plt.title('5-way K-shot test accuracy')
plt.savefig('../plots/5-way_K-shot_test_accuracy.png', dpi=300)
plt.show()

# %%
# Now we do the same for the train split:
# RelationNet
relationnet_fc_diff_mean_05_k_train = relationnet_fc_diff_mean_05_k[relationnet_fc_diff_mean_05_k['split'] == 'train']
relationnet_fc_diff_mean_05_k_train = relationnet_fc_diff_mean_05_k_train.sort_values(by=['n_shot'])
relationnet_fc_diff_mean_05_k_train.head()
# plot it
plt.figure(figsize=(10, 5))
sns.set(style="darkgrid")
# We add the standard deviation as error bars filled between
sns.lineplot(x='n_shot', y='acc_mean', data=relationnet_fc_diff_mean_05_k_train, label='RelationNet')
plt.fill_between(relationnet_fc_diff_mean_05_k_train['n_shot'], relationnet_fc_diff_mean_05_k_train['acc_mean'] - relationnet_fc_diff_mean_05_k_train['acc_std'], relationnet_fc_diff_mean_05_k_train['acc_mean'] + relationnet_fc_diff_mean_05_k_train['acc_std'], alpha=ALPHA)

# RelationNet L1
relationnet_l1_mean_05_k_train = relationnet_l1_mean_05_k[relationnet_l1_mean_05_k['split'] == 'train']
relationnet_l1_mean_05_k_train = relationnet_l1_mean_05_k_train.sort_values(by=['n_shot'])
relationnet_l1_mean_05_k_train.head()
# plot it
sns.lineplot(x='n_shot', y='acc_mean', data=relationnet_l1_mean_05_k_train, label='RelationNet L1')
plt.fill_between(relationnet_l1_mean_05_k_train['n_shot'], relationnet_l1_mean_05_k_train['acc_mean'] - relationnet_l1_mean_05_k_train['acc_std'], relationnet_l1_mean_05_k_train['acc_mean'] + relationnet_l1_mean_05_k_train['acc_std'], alpha=ALPHA)

# ProtoNet
protonet_05_k_train = protonet_05_k[protonet_05_k['split'] == 'train']
protonet_05_k_train = protonet_05_k_train.sort_values(by=['n_shot'])
protonet_05_k_train.head()
# plot it
sns.lineplot(x='n_shot', y='acc_mean', data=protonet_05_k_train, label='ProtoNet')
plt.fill_between(protonet_05_k_train['n_shot'], protonet_05_k_train['acc_mean'] - protonet_05_k_train['acc_std'], protonet_05_k_train['acc_mean'] + protonet_05_k_train['acc_std'], alpha=ALPHA)

# MatchingNet
matchingnet_05_k_train = matchingnet_05_k[matchingnet_05_k['split'] == 'train']
matchingnet_05_k_train = matchingnet_05_k_train.sort_values(by=['n_shot'])
matchingnet_05_k_train.head()
# plot it
sns.lineplot(x='n_shot', y='acc_mean', data=matchingnet_05_k_train, label='MatchingNet')
plt.fill_between(matchingnet_05_k_train['n_shot'], matchingnet_05_k_train['acc_mean'] - matchingnet_05_k_train['acc_std'], matchingnet_05_k_train['acc_mean'] + matchingnet_05_k_train['acc_std'], alpha=ALPHA)

# MAML
maml_05_k_train = maml_05_k[maml_05_k['split'] == 'train']
maml_05_k_train = maml_05_k_train.sort_values(by=['n_shot'])
maml_05_k_train.head()
# plot it
sns.lineplot(x='n_shot', y='acc_mean', data=maml_05_k_train, label='MAML')
plt.fill_between(maml_05_k_train['n_shot'], maml_05_k_train['acc_mean'] - maml_05_k_train['acc_std'], maml_05_k_train['acc_mean'] + maml_05_k_train['acc_std'], alpha=ALPHA)

plt.ylabel('Mean accuracy')
plt.xlabel('Number of shots')
plt.title('5-way K-shot train accuracy')
plt.savefig('../plots/5-way_K-shot_train_accuracy.png', dpi=300)
plt.show()

# %%
# Here we do all the C-ways 5-shots analysis
relationnet_fc_diff_mean_c_05 = pd.read_csv(CSV_FOLDER + 'relationnet_fc-diff_mean_c_05.csv')
relationnet_l1_mean_c_05 = pd.read_csv(CSV_FOLDER + 'relationnet_l1_mean_c_05.csv')
protonet_c_05 = pd.read_csv(CSV_FOLDER + 'protonet_c_05.csv')
matchingnet_c_05 = pd.read_csv(CSV_FOLDER + 'matchingnet_c_05.csv')
maml_c_05 = pd.read_csv(CSV_FOLDER + 'maml_c_05.csv')

# %%
relationnet_fc_diff_mean_c_05.head()
# Out:
#                                           name    class  split   acc_mean  \
# 0  tabula-muris_relationnet_fc-diff_mean_10_05  s2_10_5  train  94.852222
# 1  tabula-muris_relationnet_fc-diff_mean_10_05  s2_10_5    val  75.698889
# 2  tabula-muris_relationnet_fc-diff_mean_10_05  s2_10_5   test  73.744444
# 3  tabula-muris_relationnet_fc-diff_mean_20_05  s2_20_5  train  94.916111
# 4  tabula-muris_relationnet_fc-diff_mean_20_05  s2_20_5    val  62.397222
#
#     acc_std  n_way  n_shot  n_query
# 0  3.841153     10       5       15
# 1  7.144363     10       5       15
# 2  7.388371     10       5       15
# 3  2.651030     20       5       15
# 4  4.972609     20       5       15

# %%
# We make where the x axis is the number of ways and the y axis is the mean accuracy, with the standard deviation as error bars

ALPHA=0.2

# For the val split:
# RelationNet
relationnet_fc_diff_mean_c_05_val = relationnet_fc_diff_mean_c_05[relationnet_fc_diff_mean_c_05['split'] == 'val']
relationnet_fc_diff_mean_c_05_val = relationnet_fc_diff_mean_c_05_val.sort_values(by=['n_way'])
relationnet_fc_diff_mean_c_05_val.head()
# plot it
plt.figure(figsize=(10, 5))
sns.set(style="darkgrid")
# We add the standard deviation as error bars filled between
sns.lineplot(x='n_way', y='acc_mean', data=relationnet_fc_diff_mean_c_05_val, label='RelationNet')
plt.fill_between(relationnet_fc_diff_mean_c_05_val['n_way'], relationnet_fc_diff_mean_c_05_val['acc_mean'] - relationnet_fc_diff_mean_c_05_val['acc_std'], relationnet_fc_diff_mean_c_05_val['acc_mean'] + relationnet_fc_diff_mean_c_05_val['acc_std'], alpha=ALPHA)

# RelationNet L1
relationnet_l1_mean_c_05_val = relationnet_l1_mean_c_05[relationnet_l1_mean_c_05['split'] == 'val']
relationnet_l1_mean_c_05_val = relationnet_l1_mean_c_05_val.sort_values(by=['n_way'])
relationnet_l1_mean_c_05_val.head()
# plot it
sns.lineplot(x='n_way', y='acc_mean', data=relationnet_l1_mean_c_05_val, label='RelationNet L1')
plt.fill_between(relationnet_l1_mean_c_05_val['n_way'], relationnet_l1_mean_c_05_val['acc_mean'] - relationnet_l1_mean_c_05_val['acc_std'], relationnet_l1_mean_c_05_val['acc_mean'] + relationnet_l1_mean_c_05_val['acc_std'], alpha=ALPHA)

# ProtoNet
protonet_c_05_val = protonet_c_05[protonet_c_05['split'] == 'val']
protonet_c_05_val = protonet_c_05_val.sort_values(by=['n_way'])
protonet_c_05_val.head()
# plot it
sns.lineplot(x='n_way', y='acc_mean', data=protonet_c_05_val, label='ProtoNet')
plt.fill_between(protonet_c_05_val['n_way'], protonet_c_05_val['acc_mean'] - protonet_c_05_val['acc_std'], protonet_c_05_val['acc_mean'] + protonet_c_05_val['acc_std'], alpha=ALPHA)

# MatchingNet
matchingnet_c_05_val = matchingnet_c_05[matchingnet_c_05['split'] == 'val']
matchingnet_c_05_val = matchingnet_c_05_val.sort_values(by=['n_way'])
matchingnet_c_05_val.head()
# plot it
sns.lineplot(x='n_way', y='acc_mean', data=matchingnet_c_05_val, label='MatchingNet')
plt.fill_between(matchingnet_c_05_val['n_way'], matchingnet_c_05_val['acc_mean'] - matchingnet_c_05_val['acc_std'], matchingnet_c_05_val['acc_mean'] + matchingnet_c_05_val['acc_std'], alpha=ALPHA)

# MAML
maml_c_05_val = maml_c_05[maml_c_05['split'] == 'val']
maml_c_05_val = maml_c_05_val.sort_values(by=['n_way'])
maml_c_05_val.head()
# plot it
sns.lineplot(x='n_way', y='acc_mean', data=maml_c_05_val, label='MAML')
plt.fill_between(maml_c_05_val['n_way'], maml_c_05_val['acc_mean'] - maml_c_05_val['acc_std'], maml_c_05_val['acc_mean'] + maml_c_05_val['acc_std'], alpha=ALPHA)

plt.ylabel('Mean accuracy')
plt.xlabel('Number of ways')
plt.title('C-way 5-shot validation accuracy')
plt.savefig('../plots/C-way_5-shot_validation_accuracy.png', dpi=300)
plt.show()

# %%
# Now we do the same for the test split:
# RelationNet
relationnet_fc_diff_mean_c_05_test = relationnet_fc_diff_mean_c_05[relationnet_fc_diff_mean_c_05['split'] == 'test']
relationnet_fc_diff_mean_c_05_test = relationnet_fc_diff_mean_c_05_test.sort_values(by=['n_way'])
relationnet_fc_diff_mean_c_05_test.head()
# plot it
plt.figure(figsize=(10, 5))
sns.set(style="darkgrid")
# We add the standard deviation as error bars filled between
sns.lineplot(x='n_way', y='acc_mean', data=relationnet_fc_diff_mean_c_05_test, label='RelationNet')
plt.fill_between(relationnet_fc_diff_mean_c_05_test['n_way'], relationnet_fc_diff_mean_c_05_test['acc_mean'] - relationnet_fc_diff_mean_c_05_test['acc_std'], relationnet_fc_diff_mean_c_05_test['acc_mean'] + relationnet_fc_diff_mean_c_05_test['acc_std'], alpha=ALPHA)

# RelationNet L1
relationnet_l1_mean_c_05_test = relationnet_l1_mean_c_05[relationnet_l1_mean_c_05['split'] == 'test']
relationnet_l1_mean_c_05_test = relationnet_l1_mean_c_05_test.sort_values(by=['n_way'])
relationnet_l1_mean_c_05_test.head()
# plot it
sns.lineplot(x='n_way', y='acc_mean', data=relationnet_l1_mean_c_05_test, label='RelationNet L1')
plt.fill_between(relationnet_l1_mean_c_05_test['n_way'], relationnet_l1_mean_c_05_test['acc_mean'] - relationnet_l1_mean_c_05_test['acc_std'], relationnet_l1_mean_c_05_test['acc_mean'] + relationnet_l1_mean_c_05_test['acc_std'], alpha=ALPHA)

# ProtoNet
protonet_c_05_test = protonet_c_05[protonet_c_05['split'] == 'test']
protonet_c_05_test = protonet_c_05_test.sort_values(by=['n_way'])
protonet_c_05_test.head()
# plot it
sns.lineplot(x='n_way', y='acc_mean', data=protonet_c_05_test, label='ProtoNet')
plt.fill_between(protonet_c_05_test['n_way'], protonet_c_05_test['acc_mean'] - protonet_c_05_test['acc_std'], protonet_c_05_test['acc_mean'] + protonet_c_05_test['acc_std'], alpha=ALPHA)

# MatchingNet
matchingnet_c_05_test = matchingnet_c_05[matchingnet_c_05['split'] == 'test']
matchingnet_c_05_test = matchingnet_c_05_test.sort_values(by=['n_way'])
matchingnet_c_05_test.head()
# plot it
sns.lineplot(x='n_way', y='acc_mean', data=matchingnet_c_05_test, label='MatchingNet')
plt.fill_between(matchingnet_c_05_test['n_way'], matchingnet_c_05_test['acc_mean'] - matchingnet_c_05_test['acc_std'], matchingnet_c_05_test['acc_mean'] + matchingnet_c_05_test['acc_std'], alpha=ALPHA)

# MAML
maml_c_05_test = maml_c_05[maml_c_05['split'] == 'test']
maml_c_05_test = maml_c_05_test.sort_values(by=['n_way'])
maml_c_05_test.head()
# plot it
sns.lineplot(x='n_way', y='acc_mean', data=maml_c_05_test, label='MAML')
plt.fill_between(maml_c_05_test['n_way'], maml_c_05_test['acc_mean'] - maml_c_05_test['acc_std'], maml_c_05_test['acc_mean'] + maml_c_05_test['acc_std'], alpha=ALPHA)

plt.ylabel('Mean accuracy')
plt.xlabel('Number of ways')
plt.title('C-way 5-shot test accuracy')
plt.savefig('../plots/C-way_5-shot_test_accuracy.png', dpi=300)
plt.show()

# %%
# Now we do the same for the train split:
# RelationNet
relationnet_fc_diff_mean_c_05_train = relationnet_fc_diff_mean_c_05[relationnet_fc_diff_mean_c_05['split'] == 'train']
relationnet_fc_diff_mean_c_05_train = relationnet_fc_diff_mean_c_05_train.sort_values(by=['n_way'])
relationnet_fc_diff_mean_c_05_train.head()
# plot it
plt.figure(figsize=(10, 5))
sns.set(style="darkgrid")
# We add the standard deviation as error bars filled between
sns.lineplot(x='n_way', y='acc_mean', data=relationnet_fc_diff_mean_c_05_train, label='RelationNet')
plt.fill_between(relationnet_fc_diff_mean_c_05_train['n_way'], relationnet_fc_diff_mean_c_05_train['acc_mean'] - relationnet_fc_diff_mean_c_05_train['acc_std'], relationnet_fc_diff_mean_c_05_train['acc_mean'] + relationnet_fc_diff_mean_c_05_train['acc_std'], alpha=ALPHA)

# RelationNet L1
relationnet_l1_mean_c_05_train = relationnet_l1_mean_c_05[relationnet_l1_mean_c_05['split'] == 'train']
relationnet_l1_mean_c_05_train = relationnet_l1_mean_c_05_train.sort_values(by=['n_way'])
relationnet_l1_mean_c_05_train.head()
# plot it
sns.lineplot(x='n_way', y='acc_mean', data=relationnet_l1_mean_c_05_train, label='RelationNet L1')
plt.fill_between(relationnet_l1_mean_c_05_train['n_way'], relationnet_l1_mean_c_05_train['acc_mean'] - relationnet_l1_mean_c_05_train['acc_std'], relationnet_l1_mean_c_05_train['acc_mean'] + relationnet_l1_mean_c_05_train['acc_std'], alpha=ALPHA)

# ProtoNet
protonet_c_05_train = protonet_c_05[protonet_c_05['split'] == 'train']
protonet_c_05_train = protonet_c_05_train.sort_values(by=['n_way'])
protonet_c_05_train.head()
# plot it
sns.lineplot(x='n_way', y='acc_mean', data=protonet_c_05_train, label='ProtoNet')
plt.fill_between(protonet_c_05_train['n_way'], protonet_c_05_train['acc_mean'] - protonet_c_05_train['acc_std'], protonet_c_05_train['acc_mean'] + protonet_c_05_train['acc_std'], alpha=ALPHA)

# MatchingNet
matchingnet_c_05_train = matchingnet_c_05[matchingnet_c_05['split'] == 'train']
matchingnet_c_05_train = matchingnet_c_05_train.sort_values(by=['n_way'])
matchingnet_c_05_train.head()
# plot it
sns.lineplot(x='n_way', y='acc_mean', data=matchingnet_c_05_train, label='MatchingNet')
plt.fill_between(matchingnet_c_05_train['n_way'], matchingnet_c_05_train['acc_mean'] - matchingnet_c_05_train['acc_std'], matchingnet_c_05_train['acc_mean'] + matchingnet_c_05_train['acc_std'], alpha=ALPHA)

# MAML
maml_c_05_train = maml_c_05[maml_c_05['split'] == 'train']
maml_c_05_train = maml_c_05_train.sort_values(by=['n_way'])
maml_c_05_train.head()
# plot it
sns.lineplot(x='n_way', y='acc_mean', data=maml_c_05_train, label='MAML')
plt.fill_between(maml_c_05_train['n_way'], maml_c_05_train['acc_mean'] - maml_c_05_train['acc_std'], maml_c_05_train['acc_mean'] + maml_c_05_train['acc_std'], alpha=ALPHA)

plt.ylabel('Mean accuracy')
plt.xlabel('Number of ways')
plt.title('C-way 5-shot train accuracy')
plt.savefig('../plots/C-way_5-shot_train_accuracy.png', dpi=300)
plt.show()
